# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

a = -15
graph = lambda x: (a*x*x) - (10*x) +2 
x = list(range(-5, 15))
y = list(map(graph, x))
plt.plot(x, y)
plt.show()
